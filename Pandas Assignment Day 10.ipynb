# %% [markdown]
# # <center>Pandas Assignment</center>

# %% [markdown]
# Import pandas and numpy with their aliases

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Create a variable a = pd.Series([ 100, 200, 300, 400])

# %%
 a =  pd.Series([ 100, 200, 300, 400])

# %% [markdown]
# Print a, and data type

# %%
print(a)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %% [markdown]
# Using indexing access the element 300 from the series a.

# %%
print(a[2])
# Out:
# 300

# %% [markdown]
# What are the values of index for series a?

# %%
print(a.index)

print(list(a.index))
# Out:
# RangeIndex(start=0, stop=4, step=1)
# [0, 1, 2, 3]

# %% [markdown]
# Change the index to  ['c', 'a', 'b', 'd']

# %%
a.index = ['c', 'a', 'b', 'd']
print(a)
# Out:
# c    100
# a    200
# b    300
# d    400
# dtype: int64

# %% [markdown]
# Access the value in the series with index 'd'

# %%
print(a['d'])
# Out:
# 400

# %% [markdown]
# Sort the values wrt to the index and print it

# %%
print(a.sort_index())
# Out:
# a    200
# b    300
# c    100
# d    400
# dtype: int64

# %% [markdown]
# Create a new Pandas Series b having index as 'e', 'f', and 'g' and value 800,450,100 and print it

# %%
import pandas as pd

b = pd.Series([800, 450, 100], index=['e', 'f', 'g'])

print(b)
# Out:
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Append b series at the end of a series

# %%
c = pd.concat([a, b])

print(c)
# Out:
# c    100
# a    200
# b    300
# d    400
# e    800
# f    450
# g    100
# dtype: int64

# %%
#print a again after appending b into it
print(a)
# Out:
# c    100
# a    200
# b    300
# d    400
# dtype: int64

# %% [markdown]
# Sort the values in descending order of a and print the index of the sorted series

# %%
 sorted_a = a.sort_values(ascending=False)

print(sorted_a.index)
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# ### Part 1

# %% [markdown]
# Create a pandas dataframe df from the series 'a' that we used in the last section, print the dataframe

# %%
df = pd.DataFrame(a)

print(df)
# Out:
#      0
# c  100
# a  200
# b  300
# d  400

# %% [markdown]
# What is the shape of the datafarme <br>
# (also, what does it imply?)

# %%
print(df.shape)

This implies that the DataFrame has:

4 rows
1 column
# Out:
# (4, 1)

# %% [markdown]
# Hey! remember shape (7,1) implies dataframe has 7 rows and 1 column.

# %% [markdown]
# What is the index of the dataframe, is it same as the series 'a'

# %%
# yep its same as the series.
print(df.index)
# Out:
# Index(['c', 'a', 'b', 'd'], dtype='object')

# %% [markdown]
# print the head and tail of the dataframe. <br>
# Additional - (what does head and tali represent?)

# %%
print(df.head())
print(df.tail())
# Out:
#      0
# c  100
# a  200
# b  300
# d  400
#      0
# c  100
# a  200
# b  300
# d  400

# %% [markdown]
# Rename the column of the dataframe as 'points'

# %%
df.columns = ['points']

print(df)
# Out:
#    points
# c     100
# a     200
# b     300
# d     400

# %% [markdown]
# Create another Series 'fruits', which contains random names of fruits from ['orange','mango','apple']. The series should contain 7 elements, randomly selected from ['orange','mango','apple']

# %%
#Create fruits array
import random
fruits = pd.Series(
    [random.choice(['orange', 'mango', 'apple']) for i in range(7)]
)

print(fruits)
# Out:
# 0    orange
# 1     apple
# 2    orange
# 3    orange
# 4     apple
# 5     apple
# 6     mango
# dtype: object

# %%
#Create series fruits out of fruits array

fruits = ['orange', 'mango', 'apple', 'mango',]

fruits_series = pd.Series(fruits)

print(fruits_series)
# Out:
# 0    orange
# 1     mango
# 2     apple
# 3     mango
# dtype: object

# %% [markdown]
# Change the index of fruits to the index of dataframe df

# %%
fruits_series.index = df.index

print(fruits_series)
# Out:
# c    orange
# a     mango
# b     apple
# d     mango
# dtype: object

# %% [markdown]
# Add this fruits series as a new column to the dataframe df with its column name as 'fruits'
# <br>print the head of the dataframe to verify

# %%
df['fruits'] = fruits_series

print(df.head())
# Out:
#    points  fruits
# c     100  orange
# a     200   mango
# b     300   apple
# d     400   mango

# %% [markdown]
# ## Pandas Concatenation

# %% [markdown]
# Create a dataframe  d1 where the cols are  ‘city’ : [‘Chandigarh’, ‘Delhi’, ‘Kanpur’, ‘Chennai’, ‘Manali’ ] and ‘Temperature’ : [15, 22, 20, 26,-2]

# %%
d1 = pd.DataFrame({
    'city': ['Chandigarh', 'Delhi', 'Kanpur', 'Chennai', 'Manali'],
    'Temperature': [15, 22, 20, 26, -2]
})

print(d1)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# Print(d1)

# %%
print(d1)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# What is the shape of d1.

# %%
print(d1.shape)
# Out:
# (5, 2)

# %% [markdown]
# Set city = d1['city']

# %%
city = d1['city']

print(city)
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: object

# %% [markdown]
# print city <br>
# What is the type of city.

# %%
print(city)

print(type(city))
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Create another datafeame 'd2' where the columns are <br>
# 'city' - ['Bengalaru','Coimbatore','Srirangam','Pondicherry'] <br>
# 'Temperature' - [24,35,36,39]

# %%
d2 = pd.DataFrame({
    'city': ['Bengalaru', 'Coimbatore', 'Srirangam', 'Pondicherry'],
    'Temperature': [24, 35, 36, 39]
})

print(d2)
# Out:
#           city  Temperature
# 0    Bengalaru           24
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %% [markdown]
# print the shape of this dataframe

# %%
print(d2.shape)
# Out:
# (4, 2)

# %% [markdown]
# merge the two dataframes together, save it in a new dataframe named 'd3'

# %%
d3 = pd.concat([d1, d2])

print(d3)
# Out:
#           city  Temperature
# 0   Chandigarh           15
# 1        Delhi           22
# 2       Kanpur           20
# 3      Chennai           26
# 4       Manali           -2
# 0    Bengalaru           24
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %% [markdown]
# Select the part of the dataframe such that it contains cities wherer temp is less then or equal to 20 <br>
# How many cities are there?

# %%
cold_cities = d3[d3['Temperature'] <= 20]

print(cold_cities)

print("Number of cities:", len(cold_cities))
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 2      Kanpur           20
# 4      Manali           -2
# Number of cities: 3

# %% [markdown]
# Select the part of the dataframe such that it contains the cities where tempearature greater than or equal to 35

# %%
hot_cities = d3[d3['Temperature'] >= 35]

print(hot_cities)
# Out:
#           city  Temperature
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %% [markdown]
# ## Applying functions to columns and creating new columns

# %% [markdown]
# We need to create another column in d3, which contains  a boolean value for each city to indicate whether it's a union territory or not.
# - HINT: Chandigarh, Pondicherry and Delhi are only 3 union territories here.

# %%
# write function here

def is_ut(x):
    
    # write code below
    return x in ['Chandigarh', 'Delhi', 'Pondicherry']

d3['is_ut'] = d3['city'].apply(is_ut)

print(d3)
# Out:
#           city  Temperature  UnionTerritory  is_ut
# 0   Chandigarh           15            True   True
# 1        Delhi           22            True   True
# 2       Kanpur           20           False  False
# 3      Chennai           26           False  False
# 4       Manali           -2           False  False
# 0    Bengalaru           24           False  False
# 1   Coimbatore           35           False  False
# 2    Srirangam           36           False  False
# 3  Pondicherry           39            True   True

# %%
print(d3)
# Out:
#           city  Temperature  UnionTerritory  is_ut
# 0   Chandigarh           15            True   True
# 1        Delhi           22            True   True
# 2       Kanpur           20           False  False
# 3      Chennai           26           False  False
# 4       Manali           -2           False  False
# 0    Bengalaru           24           False  False
# 1   Coimbatore           35           False  False
# 2    Srirangam           36           False  False
# 3  Pondicherry           39            True   True

# %% [markdown]
# The temperatures mentioned in ‘Temperature’ column are mentioned in Celsius, we need another column which contains the same in Fahrenheit.

# %% [markdown]
# HINT -
# - Define a function c_to_f which takes input temp in celsius and returns a value with temperature in Fahrenheit.
# - To check: c_to_f(10) should return 50.

# %%
# write function here

def c_to_f(temp):
    return (temp * 9/5) + 32


d3['Fahrenheit'] = d3['Temperature'].apply(c_to_f)

print(d3)
# Out:
#           city  Temperature  UnionTerritory  is_ut  Fahrenheit
# 0   Chandigarh           15            True   True        59.0
# 1        Delhi           22            True   True        71.6
# 2       Kanpur           20           False  False        68.0
# 3      Chennai           26           False  False        78.8
# 4       Manali           -2           False  False        28.4
# 0    Bengalaru           24           False  False        75.2
# 1   Coimbatore           35           False  False        95.0
# 2    Srirangam           36           False  False        96.8
# 3  Pondicherry           39            True   True       102.2

# %%
# check function c_to_f(10)
print(c_to_f(10))
# Out:
# 50.0

# %%
# apply function c_to_f to d3 to create a column 'temp_farenhiet'
d3['temp_farenhiet'] = d3['Temperature'].apply(c_to_f)

print(d3)
# Out:
#           city  Temperature  UnionTerritory  is_ut  Fahrenheit  temp_farenhiet
# 0   Chandigarh           15            True   True        59.0            59.0
# 1        Delhi           22            True   True        71.6            71.6
# 2       Kanpur           20           False  False        68.0            68.0
# 3      Chennai           26           False  False        78.8            78.8
# 4       Manali           -2           False  False        28.4            28.4
# 0    Bengalaru           24           False  False        75.2            75.2
# 1   Coimbatore           35           False  False        95.0            95.0
# 2    Srirangam           36           False  False        96.8            96.8
# 3  Pondicherry           39            True   True       102.2           102.2

# %% [markdown]
# ## Indexing and selecting rows in DataFrame

# %% [markdown]
# Select subset of the dataframe d1 such that it contains the cities which are union territories.

# %%
ut_cities = d3[d3['is_ut'] == True]

print(ut_cities)
# Out:
#           city  Temperature  UnionTerritory  is_ut  Fahrenheit  temp_farenhiet
# 0   Chandigarh           15            True   True        59.0            59.0
# 1        Delhi           22            True   True        71.6            71.6
# 3  Pondicherry           39            True   True       102.2           102.2

# %% [markdown]
# Select a subset of the dataframe d1 such that it contains the cities which only have temperature above 90 Farenhiet.

# %%
hot_cities_f = d3[d3['temp_farenhiet'] > 90]

print(hot_cities_f)
# Out:
#           city  Temperature  UnionTerritory  is_ut  Fahrenheit  temp_farenhiet
# 1   Coimbatore           35           False  False        95.0            95.0
# 2    Srirangam           36           False  False        96.8            96.8
# 3  Pondicherry           39            True   True       102.2           102.2

# %% [markdown]
# Select only the first three rows of the dataframe d1.

# %%
print(d3.head(3))
# Out:
#          city  Temperature  UnionTerritory  is_ut  Fahrenheit  temp_farenhiet
# 0  Chandigarh           15            True   True        59.0            59.0
# 1       Delhi           22            True   True        71.6            71.6
# 2      Kanpur           20           False  False        68.0            68.0

# %% [markdown]
# Select all the rows and last two columns in the dataframe.

# %%
print(d3.iloc[:, -2:])
# Out:
#    Fahrenheit  temp_farenhiet
# 0        59.0            59.0
# 1        71.6            71.6
# 2        68.0            68.0
# 3        78.8            78.8
# 4        28.4            28.4
# 0        75.2            75.2
# 1        95.0            95.0
# 2        96.8            96.8
# 3       102.2           102.2

# %% [markdown]
# ## Groupby

# %%
# Create a dataframe using dictionary of your choice

data = {
    'Name': ['Rahul', 'Ananya', 'Vikram', 'Sneha'],
    'Age': [23, 21, 24, 22],
    'Course': ['Data Science', 'BCA', 'MBA', 'B.Tech']
}

df = pd.DataFrame(data)

print(df)
# Out:
#      Name  Age        Course
# 0   Rahul   23  Data Science
# 1  Ananya   21           BCA
# 2  Vikram   24           MBA
# 3   Sneha   22        B.Tech

# %%
# Use Groupby of single column with aggregate sum()

grouped_data = df.groupby('Course').sum()

print(grouped_data)
# Out:
#                 Name  Age
# Course
# B.Tech         Sneha   22
# BCA           Ananya   21
# Data Science   Rahul   23
# MBA           Vikram   24

# %%
# Use Groupby of single column with aggregate count()

grouped_count = df.groupby('Course').count()

print(grouped_count)
# Out:
#               Name  Age
# Course
# B.Tech           1    1
# BCA              1    1
# Data Science     1    1
# MBA              1    1

# %%
# Use Groupby of single column with aggregate min() and max()
grouped_min = df.groupby('Course').min()
grouped_max = df.groupby('Course').max()

print("Minimum values:")
print(grouped_min)

print("\nMaximum values:")
print(grouped_max)
# Out:
# Minimum values:
#                 Name  Age
# Course
# B.Tech         Sneha   22
# BCA           Ananya   21
# Data Science   Rahul   23
# MBA           Vikram   24
#
# Maximum values:
#                 Name  Age
# Course
# B.Tech         Sneha   22
# BCA           Ananya   21
# Data Science   Rahul   23
# MBA           Vikram   24

# %%
# Use Groupby of any 2 columns with aggregate mean()

grouped_mean = df.groupby(['Course', 'Name']).mean(numeric_only=True)

print(grouped_mean)
# Out:
#                       Age
# Course       Name
# B.Tech       Sneha   22.0
# BCA          Ananya  21.0
# Data Science Rahul   23.0
# MBA          Vikram  24.0

# %%
# Use Groupby of any 2 columns with aggregate min() and max()

grouped_min = df.groupby(['Course', 'Name']).min(numeric_only=True)
grouped_max = df.groupby(['Course', 'Name']).max(numeric_only=True)

print("Minimum values:")
print(grouped_min)

print("\nMaximum values:")
print(grouped_max)
# Out:
# Minimum values:
#                      Age
# Course       Name
# B.Tech       Sneha    22
# BCA          Ananya   21
# Data Science Rahul    23
# MBA          Vikram   24
#
# Maximum values:
#                      Age
# Course       Name
# B.Tech       Sneha    22
# BCA          Ananya   21
# Data Science Rahul    23
# MBA          Vikram   24

# %% [markdown]
# ## Data Range

# %% [markdown]
# Create a pandas daterange where starting date is 1st of January,2020 and end date is 1st of April 2021, store it in a new variable named 'a'

# %%
a = pd.date_range(start='2020-01-01', end='2021-04-01')

print(a)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-27', '2021-03-28', '2021-03-29', '2021-03-30',
#                '2021-03-31', '2021-04-01'],
#               dtype='datetime64[ns]', length=457, freq='D')

# %% [markdown]
# print a

# %%
print(a)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-27', '2021-03-28', '2021-03-29', '2021-03-30',
#                '2021-03-31', '2021-04-01'],
#               dtype='datetime64[ns]', length=457, freq='D')

# %% [markdown]
# What is the len of a?

# %%
print(len(a))
# Out:
# 457

# %% [markdown]
# What is the type of a?

# %%
print(type(a))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
